# %% [markdown]
# ## Python Rules to define a variable

# %%
name = "akash"

# %%
_name = "akash"

# %%
name_ = "akash"

# %%
Full_Name = "akash panwar"

# %%
name-A = "akash"
# Out:
#   Cell In[6], line 1
#     name-A = "akash"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
10name = "akash"
# Out:
#   Cell In[7], line 1
#     10name = "akash"
#      ^
# SyntaxError: invalid decimal literal

# %%
&name = "akash"
# Out:
#   Cell In[8], line 1
#     &name = "akash"
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # variable in python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "GEEKSFORGEEKS"
id(a)
print("id of a:",id(a))

b = 20
id(b),
print("id of b:",id(b))
# Out:
# id of a: 2472978191792
# id of b: 140709758473608

# %%
print(a)
# Out:
# GEEKSFORGEEKS

# %%
a = 50
b = 60
print(a)
print(b)
#python is a case sensetive
# Out:
# 50
# 60

# %% [markdown]
# ## Data types in Python

# %% [markdown]
# ### 1. string type data type

# %%
# String
name = "akash"

# %%
# Type() -----> type function is used to check  the type of data
# ()---> Paranthesis
type(name)
# Out:
# str

# %%
num = 10
type(num)
# Out:
# int

# %%
# converting integer data type into string (str) data type and printing directly
str(num)
# here str() is an in built function in python
# Out:
# '10'

# %%
# converting integer data type into string str() data type and firstly sorting the result in the variable 
string = str(num)

# %%
string
# Out:
# '10'

# %%
print(string)
print(type(string))
# Out:
# 10
# <class 'str'>

# %% [markdown]
# ## string indexing and slicing

# %%
string = "akash"

# %%
#string[starting_index:ending_index_step_size]

# %%
string[0:3]
# Out:
# 'aka'

# %%
string[-3:]
# Out:
# 'ash'

# %%
string[0:5]
# Out:
# 'akash'

# %%
string[0:-1:2]
# Out:
# 'aa'
